# %% [markdown]
# # Data Visulization
# ## Planets randome visualize
# > ### abed alaziz alsalahat
# > #### 26/May/2021  19:20
# ___
# ___
# ___

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('planets')
df
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.relplot(x='mass', y='year', hue=df.year.tolist(), data=df);

# %%
year_mean = df.groupby('orbital_period', as_index=False).mean()

year_mean
# Out:
#      orbital_period  number  mass  distance    year
# 0          0.090706     1.0   NaN   1200.00  2011.0
# 1          0.240104     2.0   NaN   1180.00  2011.0
# 2          0.342887     2.0   NaN   1180.00  2011.0
# 3          0.355000     1.0   NaN       NaN  2013.0
# 4          0.453285     3.0   NaN     38.70  2011.0
# ..              ...     ...   ...       ...     ...
# 983    40000.000000     1.0   NaN       NaN  2011.0
# 984    69000.000000     4.0   NaN     39.94  2008.0
# 985   170000.000000     4.0   NaN     39.94  2008.0
# 986   318280.000000     1.0   NaN      7.69  2008.0
# 987   730000.000000     1.0   NaN       NaN  2006.0
#
# [988 rows x 5 columns]

# %%
graph = sns.barplot(x="number", y="distance", data=year_mean, ci=None)

# %%
sns.lmplot(x="mass", y="distance", data=year_mean);

# %%
graph = sns.relplot(x="mass", y="orbital_period", hue=df.year.tolist(), data=df)
